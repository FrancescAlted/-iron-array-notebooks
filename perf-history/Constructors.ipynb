# %% [markdown]
# # Parallel Constructors

# %%
# %load_ext memprofiler

# %% [markdown]
# ## Basic constructors

# %% [markdown]
# ### Floating point: ones

# %% [markdown]
# #### In-memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory ones float32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# ones  time -> 0.0

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk ones float32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# ones  time -> 0.003

# %% [markdown]
# ### Floating point: full

# %% [markdown]
# #### In-memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory full float32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# full  time -> 0.0

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk full float32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# full  time -> 0.003

# %% [markdown]
# ### Floating point: linspace

# %% [markdown]
# #### In-memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory linspace float32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# linspace  time -> 0.323

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk linspace float32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# linspace  time -> 0.335

# %% [markdown]
# ### Integers: ones

# %% [markdown]
# #### In-memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory ones int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# ones  time -> 0.0

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk ones int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# ones  time -> 0.003

# %% [markdown]
# ### Integers: full

# %% [markdown]
# #### In-memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory full int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# full  time -> 0.0

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk full int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# full  time -> 0.003

# %% [markdown]
# ### Integers: arange

# %% [markdown]
# #### In-memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory arange int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# arange  time -> 0.324

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk arange int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# arange  time -> 0.326

# %% [markdown]
# ## Continuous distributions (floating point data)

# %% [markdown]
# ### Normal

# %% [markdown]
# #### In-Memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory standard_normal float32 10
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# standard_normal  time -> 0.303

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory standard_normal float32 0
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# standard_normal  time -> 0.273

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk standard_normal float32 10
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# standard_normal  time -> 1.646

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk standard_normal float32 0
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# standard_normal  time -> 1.9

# %% [markdown]
# ## Discrete distributions (integer data)

# %% [markdown]
# ### Poisson

# %% [markdown]
# #### In-Memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory poisson int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# poisson  time -> 0.304

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk poisson int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# poisson  time -> 1.342

# %% [markdown]
# ### User Defined Functions

# %% [markdown]
# #### In-Memory

# %%
# %rm -rf iarray_constr_udf.dat
# %run -m mprof run -o iarray_constr_udf.dat iarray_constr_udf.py memory
# %run -m mprof plot iarray_constr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# udf time -> 0.094

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr_udf.dat
# %run -m mprof run -o iarray_constr_udf.dat iarray_constr_udf.py disk
# %run -m mprof plot iarray_constr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# udf time -> 0.321

# %% [markdown]
# ## Discrete distributions (integer data)

# %% [markdown]
# ### Poisson

# %% [markdown]
# #### In-Memory

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py memory poisson int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# poisson  time -> 0.312

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr.dat
# %run -m mprof run -o iarray_constr.dat iarray_constr.py disk poisson int32
# %run -m mprof plot iarray_constr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# poisson  time -> 1.334

# %% [markdown]
# ### User Defined Functions

# %% [markdown]
# #### In-Memory

# %%
# %rm -rf iarray_constr_udf.dat
# %run -m mprof run -o iarray_constr_udf.dat iarray_constr_udf.py memory
# %run -m mprof plot iarray_constr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# udf time -> 0.093

# %% [markdown]
# #### On-Disk

# %%
# %rm -rf iarray_constr_udf.dat
# %run -m mprof run -o iarray_constr_udf.dat iarray_constr_udf.py disk
# %run -m mprof plot iarray_constr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# udf time -> 0.319
