# %% [markdown]
# # Expression Evaluation

# %%
# %load_ext memprofiler

# %% [markdown]
# ## Expression Evaluation (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.525
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 0.35

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.213
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 0.581

# %% [markdown]
# ## Expression Evaluation (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.034617 seconds
# open  time -> 0.001
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 2.428

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.036869 seconds
# open  time -> 0.002
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 2.781

# %% [markdown]
# ## Expression Evaluation UDF (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.212
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f6ef03a2090>  time -> 0.345

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.204
# cratio: 14.622
# mean  time -> 0.346

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f70d993d810>  time -> 0.527

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.199
# cratio: 14.622
# trans  time -> 0.574

# %% [markdown]
# ## Expression Evaluation UDF (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.036511 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7fa78d24b130>  time -> 2.342

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.037563 seconds
# open  time -> 0.002
# cratio: 14.622
# mean  time -> 2.395

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.035922 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f7ce6a8ff40>  time -> 2.205

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.038698 seconds
# open  time -> 0.002
# cratio: 14.622
# trans  time -> 2.816
