# %% [markdown]
# # Expression Evaluation

# %%
# %load_ext memprofiler

# %% [markdown]
# ## Expression Evaluation (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.18
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 0.361

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.176
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 0.575

# %% [markdown]
# ## Expression Evaluation (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.023484 seconds
# open  time -> 0.001
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 2.355

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.026582 seconds
# open  time -> 0.002
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 2.872

# %% [markdown]
# ## Expression Evaluation UDF (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.189
# cratio: 14.622
# <iarray.expression.Expr object at 0x7fcde25c0d60>  time -> 0.312

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.182
# cratio: 14.622
# mean  time -> 0.352

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.179
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f181e734cc0>  time -> 0.532

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.18
# cratio: 14.622
# trans  time -> 0.601

# %% [markdown]
# ## Expression Evaluation UDF (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.027244 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f4f55c7aef0>  time -> 2.373

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.027015 seconds
# open  time -> 0.002
# cratio: 14.622
# mean  time -> 2.38

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.028332 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f26a2f10db0>  time -> 2.298

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# %run save_data.py iarray_expr_udf.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.02738 seconds
# open  time -> 0.002
# cratio: 14.622
# trans  time -> 2.849
