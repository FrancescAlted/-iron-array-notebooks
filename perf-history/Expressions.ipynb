# %% [markdown]
# # Expression Evaluation

# %%
# %load_ext memprofiler
# %matplotlib inline

# %% [markdown]
# ## Expression Evaluation (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.203
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 0.352

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.197
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 0.571

# %% [markdown]
# ## Expression Evaluation (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.034032 seconds
# open  time -> 0.002
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 2.393

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.033614 seconds
# open  time -> 0.002
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 2.864

# %% [markdown]
# ## Expression Evaluation UDF (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.205
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f59de0c3cc0>  time -> 0.318
# mean  time -> 0.318

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.197
# cratio: 14.622
# mean  time -> 0.357

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.193
# cratio: 14.622
# <iarray.expression.Expr object at 0x7fadb8302c70>  time -> 0.534
# trans  time -> 0.534

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.196
# cratio: 14.622
# trans  time -> 0.587

# %% [markdown]
# ## Expression Evaluation UDF (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.034006 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7ff102cb19f0>  time -> 0.63
# mean  time -> 0.63

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.035086 seconds
# open  time -> 0.002
# cratio: 14.622
# mean  time -> 2.326

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.034503 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f053406f900>  time -> 0.746
# trans  time -> 0.746

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.035694 seconds
# open  time -> 0.002
# cratio: 14.622
# trans  time -> 2.792
