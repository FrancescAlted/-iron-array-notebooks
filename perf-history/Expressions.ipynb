# %% [markdown]
# # Expression Evaluation

# %%
# %load_ext memprofiler

# %% [markdown]
# ## Expression Evaluation (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.685
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 0.355

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py load trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.208
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 0.577

# %% [markdown]
# ## Expression Evaluation (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open mean
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.031507 seconds
# open  time -> 0.002
# cratio: 14.622
# (((o0 + o1) + o2) / 3)  time -> 2.392

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr.dat
# %run -m mprof run -o iarray_expr.dat iarray_expr.py open trans
# %run -m mprof plot iarray_expr.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.032275 seconds
# open  time -> 0.002
# cratio: 14.622
# ((tan(o0) * ((sin(o0) * sin(o1)) + cos(o1))) + (sqrt(o2) * 2))  time -> 2.861

# %% [markdown]
# ## Expression Evaluation UDF (In-Memory)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.207
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f15a3d61b30>  time -> 0.331

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.203
# cratio: 14.622
# mean  time -> 0.385

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.198
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f0e069a1d60>  time -> 0.554

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py load trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.199
# cratio: 14.622
# trans  time -> 0.575

# %% [markdown]
# ## Expression Evaluation UDF (On-Disk)

# %% [markdown]
# ### Mean evaluation

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.032319 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7fdbaf674720>  time -> 2.411

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open mean lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.033395 seconds
# open  time -> 0.001
# cratio: 14.622
# mean  time -> 2.47

# %% [markdown]
# ### Expressions with transcendental functions

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.033644 seconds
# open  time -> 0.002
# cratio: 14.622
# <iarray.expression.Expr object at 0x7f63cc7f2db0>  time -> 2.252

# %%
# %rm -rf iarray_expr_udf.dat
# %run -m mprof run -o iarray_expr_udf.dat iarray_expr_udf.py open trans lazy
# %run -m mprof plot iarray_expr_udf.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 3
#      Directories: 0
#    Evicted Pages: 180234 (704M)
#          Elapsed: 0.034452 seconds
# open  time -> 0.002
# cratio: 14.622
# trans  time -> 2.708
