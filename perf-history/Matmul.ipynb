# %% [markdown]
# # Linear Algebra

# %%
# %load_ext memprofiler

# %% [markdown]
# ## Matrix Multiplication

# %% [markdown]
# ### In-Memory

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py load matmul
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.40059 seconds
# matmul_params time -> 0.003
# load time -> 5.398
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# numpy2iarray time -> 0.06
# type   : IArray
# shape  : (25000, 1000)
# chunks : (4160, 1040)
# blocks : (104, 104)
# cratio : 292.60
#
# matmul  time -> 10.678

# %% [markdown]
# ### On-Disk

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py open matmul
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.34007 seconds
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 1.6e-05 seconds
# matmul_params time -> 0.023
# open time -> 0.001
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# numpy2iarray time -> 0.065
# type   : IArray
# shape  : (25000, 1000)
# chunks : (4160, 1040)
# blocks : (104, 104)
# cratio : 292.68
#
# matmul  time -> 12.519

# %% [markdown]
# ## Matrix Multiplication of transposed operands

# %% [markdown]
# ### In-Memory

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py load transpose
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.40014 seconds
# matmul_params time -> 0.003
# load time -> 5.389
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# numpy2iarray time -> 0.06
# type   : IArray
# shape  : (25000, 1000)
# chunks : (4160, 1040)
# blocks : (104, 104)
# cratio : 292.60
#
# am  transpose  time -> 0.001
# bm  transpose  time -> 0.0
# a copy time -> 17.998
# b copy time -> 0.306

# %% [markdown]
# ### On-Disk

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py open transpose
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.12959 seconds
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 1.5e-05 seconds
# matmul_params time -> 0.003
# open time -> 0.001
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# numpy2iarray time -> 0.065
# type   : IArray
# shape  : (25000, 1000)
# chunks : (4160, 1040)
# blocks : (104, 104)
# cratio : 292.68
#
# am  transpose  time -> 0.001
# bm  transpose  time -> 0.0
# a copy time -> 31.539
# b copy time -> 0.276
