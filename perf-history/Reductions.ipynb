# %% [markdown]
# # Reductions

# %%
# %load_ext memprofiler

# %% [markdown]
# # Reductions (In-Memory)

# %% [markdown]
# ## Mean

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load mean
# %run -m mprof plot iarray_red.dat -t "ironArray mean memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.503
# cratio: 15.429
# mean time -> 1.129

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load mean True
# %run -m mprof plot iarray_red.dat -t "ironArray mean oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.209
# cratio: 15.429
# mean time -> 2.949

# %% [markdown]
# ## Sum

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load sum
# %run -m mprof plot iarray_red.dat -t "ironArray sum memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# sum time -> 0.911

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load sum True
# %run -m mprof plot iarray_red.dat -t "ironArray sum oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.2
# cratio: 15.429
# sum time -> 2.733

# %% [markdown]
# ## Prod

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load prod
# %run -m mprof plot iarray_red.dat -t "ironArray prod memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.198
# cratio: 15.429
# prod time -> 0.915

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load prod True
# %run -m mprof plot iarray_red.dat -t "ironArray prod oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.199
# cratio: 15.429
# prod time -> 2.756

# %% [markdown]
# ## Max

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load max
# %run -m mprof plot iarray_red.dat -t "ironArray max memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.197
# cratio: 15.429
# max time -> 1.011

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load max True
# %run -m mprof plot iarray_red.dat -t "ironArray max oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.197
# cratio: 15.429
# max time -> 2.791

# %% [markdown]
# ## Min

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load min
# %run -m mprof plot iarray_red.dat -t "ironArray min memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.201
# cratio: 15.429
# min time -> 0.955

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load min True
# %run -m mprof plot iarray_red.dat -t "ironArray min oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.201
# cratio: 15.429
# min time -> 2.871

# %% [markdown]
# ## Var

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load var
# %run -m mprof plot iarray_red.dat -t "ironArray var memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.201
# cratio: 15.429
# var time -> 5.407

# %% [markdown]
# ## Std

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load std
# %run -m mprof plot iarray_red.dat -t "ironArray std memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# std time -> 5.403

# %% [markdown]
# ## Median

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load median
# %run -m mprof plot iarray_red.dat -t "ironArray median memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.201
# cratio: 15.429
# median time -> 6.217

# %% [markdown]
# ## Nanmean

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanmean
# %run -m mprof plot iarray_red.dat -t "ironArray nanmean memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# nanmean time -> 3.04

# %% [markdown]
# ## Nansum

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nansum
# %run -m mprof plot iarray_red.dat -t "ironArray nansum memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# nansum time -> 1.211

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nansum True
# %run -m mprof plot iarray_red.dat -t "ironArray nansum oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.201
# cratio: 15.429
# nansum time -> 2.832

# %% [markdown]
# ## Nanprod

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanprod
# %run -m mprof plot iarray_red.dat -t "ironArray nanprod memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.201
# cratio: 15.429
# nanprod time -> 1.188

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanprod True
# %run -m mprof plot iarray_red.dat -t "ironArray nanprod oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# nanprod time -> 2.824

# %% [markdown]
# ## Nanmax

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanmax
# %run -m mprof plot iarray_red.dat -t "ironArray nanmax memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.203
# cratio: 15.429
# nanmax time -> 1.003

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanmax True
# %run -m mprof plot iarray_red.dat -t "ironArray nanmax oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.197
# cratio: 15.429
# nanmax time -> 2.82

# %% [markdown]
# ## Nanmin

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanmin
# %run -m mprof plot iarray_red.dat -t "ironArray nanmin memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# nanmin time -> 1.022

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanmin True
# %run -m mprof plot iarray_red.dat -t "ironArray nanmin oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.197
# cratio: 15.429
# nanmin time -> 2.818

# %% [markdown]
# ## Nanvar

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanvar
# %run -m mprof plot iarray_red.dat -t "ironArray nanvar memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.198
# cratio: 15.429
# nanvar time -> 5.65

# %% [markdown]
# ## Nanstd

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanstd
# %run -m mprof plot iarray_red.dat -t "ironArray nanstd memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# nanstd time -> 5.547

# %% [markdown]
# ## Nanmedian

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py load nanmedian
# %run -m mprof plot iarray_red.dat -t "ironArray nanmedian memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# load  time -> 0.202
# cratio: 15.429
# nanmedian time -> 6.239

# %% [markdown]
# # Reductions (On-Disk)

# %% [markdown]
# ## Mean

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open mean
# %run -m mprof plot iarray_red.dat -t "ironArray mean memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.036579 seconds
# open  time -> 0.001
# cratio: 15.429
# mean time -> 1.728

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open mean True
# %run -m mprof plot iarray_red.dat -t "ironArray mean oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037751 seconds
# open  time -> 0.001
# cratio: 15.429
# mean time -> 3.019

# %% [markdown]
# ## Sum

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open sum
# %run -m mprof plot iarray_red.dat -t "ironArray sum memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.03771 seconds
# open  time -> 0.001
# cratio: 15.429
# sum time -> 1.604

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open sum True
# %run -m mprof plot iarray_red.dat -t "ironArray sum oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037928 seconds
# open  time -> 0.001
# cratio: 15.429
# sum time -> 2.914

# %% [markdown]
# ## Prod

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open prod
# %run -m mprof plot iarray_red.dat -t "ironArray prod memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037849 seconds
# open  time -> 0.001
# cratio: 15.429
# prod time -> 1.566

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open prod True
# %run -m mprof plot iarray_red.dat -t "ironArray prod oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037754 seconds
# open  time -> 0.001
# cratio: 15.429
# prod time -> 2.796

# %% [markdown]
# ## Max

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open max
# %run -m mprof plot iarray_red.dat -t "ironArray max memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037902 seconds
# open  time -> 0.001
# cratio: 15.429
# max time -> 1.638

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open max True
# %run -m mprof plot iarray_red.dat -t "ironArray max oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037761 seconds
# open  time -> 0.001
# cratio: 15.429
# max time -> 2.894

# %% [markdown]
# ## Min

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open min
# %run -m mprof plot iarray_red.dat -t "ironArray min memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037938 seconds
# open  time -> 0.001
# cratio: 15.429
# min time -> 1.588

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open min True
# %run -m mprof plot iarray_red.dat -t "ironArray min oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037476 seconds
# open  time -> 0.001
# cratio: 15.429
# min time -> 2.981

# %% [markdown]
# ## Var

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open var
# %run -m mprof plot iarray_red.dat -t "ironArray var memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037708 seconds
# open  time -> 0.001
# cratio: 15.429
# var time -> 5.549

# %% [markdown]
# ## Std

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open std
# %run -m mprof plot iarray_red.dat -t "ironArray std memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038169 seconds
# open  time -> 0.001
# cratio: 15.429
# std time -> 5.47

# %% [markdown]
# ## Median

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open median
# %run -m mprof plot iarray_red.dat -t "ironArray median memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037955 seconds
# open  time -> 0.001
# cratio: 15.429
# median time -> 6.755

# %% [markdown]
# ## Nanmean

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanmean
# %run -m mprof plot iarray_red.dat -t "ironArray nanmean memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038558 seconds
# open  time -> 0.001
# cratio: 15.429
# nanmean time -> 2.985

# %% [markdown]
# ## Nansum

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nansum
# %run -m mprof plot iarray_red.dat -t "ironArray nansum memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.039161 seconds
# open  time -> 0.001
# cratio: 15.429
# nansum time -> 1.801

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nansum True
# %run -m mprof plot iarray_red.dat -t "ironArray nansum oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038481 seconds
# open  time -> 0.001
# cratio: 15.429
# nansum time -> 2.959

# %% [markdown]
# ## Nanprod

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanprod
# %run -m mprof plot iarray_red.dat -t "ironArray nanprod memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038505 seconds
# open  time -> 0.001
# cratio: 15.429
# nanprod time -> 1.766

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanprod True
# %run -m mprof plot iarray_red.dat -t "ironArray nanprod oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037847 seconds
# open  time -> 0.001
# cratio: 15.429
# nanprod time -> 2.947

# %% [markdown]
# ## Nanmax

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanmax
# %run -m mprof plot iarray_red.dat -t "ironArray nanmax memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038321 seconds
# open  time -> 0.001
# cratio: 15.429
# nanmax time -> 1.704

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanmax True
# %run -m mprof plot iarray_red.dat -t "ironArray nanmax oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038056 seconds
# open  time -> 0.001
# cratio: 15.429
# nanmax time -> 2.945

# %% [markdown]
# ## Nanmin

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanmin
# %run -m mprof plot iarray_red.dat -t "ironArray nanmin memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037711 seconds
# open  time -> 0.001
# cratio: 15.429
# nanmin time -> 1.593

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanmin True
# %run -m mprof plot iarray_red.dat -t "ironArray nanmin oneshot memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038096 seconds
# open  time -> 0.001
# cratio: 15.429
# nanmin time -> 2.915

# %% [markdown]
# ## Nanvar

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanvar
# %run -m mprof plot iarray_red.dat -t "ironArray nanvar memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038195 seconds
# open  time -> 0.001
# cratio: 15.429
# nanvar time -> 5.629

# %% [markdown]
# ## Nanstd

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanstd
# %run -m mprof plot iarray_red.dat -t "ironArray nanstd memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.037849 seconds
# open  time -> 0.001
# cratio: 15.429
# nanstd time -> 5.63

# %% [markdown]
# ## Nanmedian

# %%
# %rm -rf iarray_red.dat
# %run -m mprof run -o iarray_red.dat iarray_red.py open nanmedian
# %run -m mprof plot iarray_red.dat -t "ironArray nanmedian memory consumption"
# %run save_data.py iarray_red.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 172028 (671M)
#          Elapsed: 0.038152 seconds
# open  time -> 0.001
# cratio: 15.429
# nanmedian time -> 6.657
