# %% [markdown]
# # Linear Algebra

# %%
# %load_ext memprofiler

# %% [markdown]
# ## Matrix Multiplication

# %% [markdown]
# ### In-Memory

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py load matmul
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# %run save_data.py iarray_linalgebra.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.11864 seconds
# matmul_params time -> 0.003
# load time -> 5.284
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# numpy2iarray time -> 0.059
# type   : IArray
# shape  : (25000, 1000)
# chunks : (4160, 1040)
# blocks : (104, 104)
# cratio : 292.60
#
# matmul  time -> 10.904

# %% [markdown]
# ### On-Disk

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py open matmul
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# %run save_data.py iarray_linalgebra.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.31517 seconds
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 1.6e-05 seconds
# matmul_params time -> 0.003
# open time -> 0.001
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# numpy2iarray time -> 0.063
# type   : IArray
# shape  : (25000, 1000)
# chunks : (4160, 1040)
# blocks : (104, 104)
# cratio : 292.68
#
# matmul  time -> 12.73

# %% [markdown]
# ## Copy of a transposed matrix

# %% [markdown]
# ### In-Memory

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py load transpose
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# %run save_data.py iarray_linalgebra.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.35951 seconds
# matmul_params time -> 0.003
# load time -> 5.32
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# am  transpose  time -> 0.0
# a copy time -> 17.744

# %% [markdown]
# ### On-Disk

# %%
# %rm -rf iarray_linalgebra.dat
# %run -m mprof run -o iarray_linalgebra.dat iarray_linalgebra.py open transpose
# %run -m mprof plot iarray_linalgebra.dat -t "ironArray memory consumption"
# %run save_data.py iarray_linalgebra.dat
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 0.32047 seconds
#            Files: 1
#      Directories: 0
#    Evicted Pages: 2185047 (8G)
#          Elapsed: 1e-05 seconds
# matmul_params time -> 0.003
# open time -> 0.001
# type   : IArray
# shape  : (100000, 25000)
# chunks : (4160, 4160)
# blocks : (104, 104)
# cratio : 2.71
#
# am  transpose  time -> 0.0
# a copy time -> 31.855
